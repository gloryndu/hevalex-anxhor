# %% [markdown]
# # Housing Data (home value)
# ### Data type: ZHVI all homes(SF, condo/co-op) seasonally adjusted,     GEOGRAPHY (city)
# ##### ZHVI: Zillow Home Value Index — it represents a typical home value (not average or median) in a region.
# ##### All Homes (SFR(single family residential), Condo/Co-op): Includes all residential property types:
# ##### Time Series: Values tracked monthly over time
# ##### Smoothed: Short-term fluctuations are reduced to make trends clearer
# ##### Seasonally Adjusted: Adjusted to remove regular seasonal effects (e.g., summer sales spikes)

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
main_df = pd.read_csv("City_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv")
main_df = pd.DataFrame(main_df)
main_df
# Out:
#        RegionID  SizeRank       RegionName RegionType StateName State  \
# 0          6181         0         New York       city        NY    NY
# 1         12447         1      Los Angeles       city        CA    CA
# 2         39051         2          Houston       city        TX    TX
# 3         17426         3          Chicago       city        IL    IL
# 4          6915         4      San Antonio       city        TX    TX
# ...         ...       ...              ...        ...       ...   ...
# 21495     40937     30062  Slaughter Beach       city        DE    DE
# 21496     44782     30062             Cove       city        TX    TX
# 21497     47606     30062           Scurry       city        TX    TX
# 21498     47855     30062    Stirling City       city        CA    CA
# 21499     49224     30062              Ila       city        GA    GA
#
#                                        Metro          CountyName  \
# ...

# %% [markdown]
# ### Task: selecting the city in maryland by parsing the data by states

# %%
md_states = main_df[main_df['State']=='MD']
md_states
# Out:
#        RegionID  SizeRank       RegionName RegionType StateName State  \
# 35         3523        35        Baltimore       city        MD    MD
# 78         7081        79    Silver Spring       city        MD    MD
# 269        4810       273        Frederick       city        MD    MD
# 353       35593       358           Laurel       city        MD    MD
# 416       33714       421        Rockville       city        MD    MD
# ...         ...       ...              ...        ...       ...   ...
# 21251    162280     28473         Rosemont       city        MD    MD
# 21321     12558     28607  Mardela Springs       city        MD    MD
# 21352     10000     28607      Bloomington       city        MD    MD
# 21483      9559     30062       Galesville       city        MD    MD
# 21487      4769     30062      Fort Howard       city        MD    MD
#
#                                               Metro             CountyName  \
# ...

# %%
baltimore = md_states[md_states['RegionName']=='Baltimore']
baltimore
# Out:
#     RegionID  SizeRank RegionName RegionType StateName State  \
# 35      3523        35  Baltimore       city        MD    MD
#
#                             Metro      CountyName    2000-01-31    2000-02-29  \
# 35  Baltimore-Columbia-Towson, MD  Baltimore City  63392.062798  63368.848196
#
#      2000-03-31    2000-04-30    2000-05-31    2000-06-30   2000-07-31  \
# 35  63391.30673  63457.372558  63627.473609  63823.684502  64031.50999
#
#       2000-08-31    2000-09-30    2000-10-31    2000-11-30    2000-12-31  \
# 35  64206.545684  64376.607722  64580.641683  64790.722386  65012.840817
#
#       2001-01-31    2001-02-28    2001-03-31    2001-04-30    2001-05-31  \
# 35  65145.150363  65250.949016  65314.417327  65397.782984  65304.249319
#
#       2001-06-30    2001-07-31    2001-08-31    2001-09-30    2001-10-31  \
# 35  65332.718915  65585.269472  66035.634234  66446.794746  66778.547916
#
#       2001-11-30    2001-12-31   2002-01-31    2002-02-28    2002-03-31  \
# ...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # need to be able to explain this

# %%
value_cols = baltimore.columns[8:]  
baltimore_melted = baltimore.melt(
    id_vars=['RegionName'], 
    value_vars=value_cols,
    var_name='Date', 
    value_name='HomeValue'
)


baltimore_melted['Date'] = pd.to_datetime(baltimore_melted['Date'])

plt.figure(figsize=(12, 6))
plt.plot(baltimore_melted['Date'], baltimore_melted['HomeValue'])
plt.title('Baltimore Home Values Over Time')
plt.xlabel('Date')
plt.ylabel('ZHVI Home Value ($)')
plt.grid(True)
plt.tight_layout()
plt.show()
